# %%
import pickle
import numpy as np


class ImageObject:
    def __init__(self, data, label):
        self.data = data
        self.label = label
        self.red = data[:, :, 0]
        self.green = data[:, :, 1]
        self.blue = data[:, :, 2]
        self.grayscale = np.dot(data[..., :3], [0.299, 0.587, 0.114])

    def __repr__(self):
        return (
            f"<ImageObject label={self.label} grayscale_shape={self.grayscale.shape}>"
        )


def load_cifar10():
    try:
        with open("../dataset_cache.pkl", "rb") as f:
            train_data, test_data = pickle.load(f)
        print("Success!")
        print(train_data[0])
        return train_data, test_data

    except FileNotFoundError:
        print("Cache file not found! Please run the setup script first.")
        return [], []

train_data = []
test_data = []
train_data, test_data = load_cifar10()

print(f"Train size: {len(train_data)}")
print(f"Test size: {len(test_data)}")
xy_train = train_data[:40000]
xy_test = train_data[40000:]
# Out:
# Success!
# <ImageObject label=frog grayscale_shape=(32, 32)>
# Train size: 50000
# Test size: 300000

# %%
from collections import Counter
class k_nn_Classifier:
    def __init__(self, k, train_data) -> None:
        self.data = np.array([i.data.flatten() for i in train_data]).astype(np.int16)
        self.reds = np.array([i.red.flatten() for i in train_data])
        self.greens = np.array([i.green.flatten() for i in train_data])
        self.blues = np.array([i.blue.flatten() for i in train_data])
        self.grays = np.array([i.grayscale.flatten() for i in train_data])
        self.labels = np.array([i.label for i in train_data])
        self.k = k

    def __repr__(self) -> str:
        return f"Data: {len(self.data)}, Labels: {len(self.labels)} Looking at {self.k} neighbors"

    def test(self, test_data, color, metric, k = self.k):
        # Basic grayscale tester with manhattan distance
        results = []
        test_grays = np.array([i.grayscale.flatten() for i in test_data])
        test_img_data = np.array([i.data.flatten() for i in test_data]).astype(np.int16)
        test_labels = [i.label for i in test_data]
        print(
            f"Testing {len(test_data)} images against {len(self.grays)} training samples..."
        )
        gray_count, data_count = 0, 0
        for i in range(len(test_grays)):
            gray_diffs = self.grays - test_grays[i]
            img_diffs = self.data - test_img_data[i]
            gray_abs_diffs = np.abs(gray_diffs)
            img_abs_diffs = np.abs(img_diffs)
            gray_distances = np.sum(gray_abs_diffs, axis=1)
            img_distances = np.sum(img_abs_diffs, axis = 1)
            gray_k_indices = np.argpartition(gray_distances, self.k)[:self.k]
            img_k_indices = np.argpartition(img_distances, self.k)[:self.k]
            gray_k_labels = self.labels[gray_k_indices]
            img_k_labels = self.labels[img_k_indices]
            gray_predicted_label = Counter(gray_k_labels).most_common(1)[0][0]
            img_predicted_label = Counter(img_k_labels).most_common(1)[0][0]
            results.append((gray_predicted_label, img_predicted_label))
            acc_label = test_labels[i]
            if gray_predicted_label == acc_label:
                gray_count += 1
            if img_predicted_label == acc_label:
                data_count += 1
            gray_acc = (gray_count/(i+1))*100
            data_acc = (data_count/(i+1))*100
            if i % 100 == 0:
                print(
                    f"Processed {i}/{len(test_grays)} \n| Pred: {gray_predicted_label}, Accuracy: {gray_acc:2f}% \n| Pred: {img_predicted_label}, Accuracy: {data_acc:2f}% \n| Acctual {test_labels[i]}"
                )
        return results

# %%
classifier = k_nn_Classifier(2, xy_train)
print(classifier)
results = classifier.test(xy_test, None, None)
print(results)
# Out:
# Data: 40000, Labels: 40000 Looking at 2 neighbors
# Testing 10000 images against 40000 training samples...
# Processed 0/10000
# | Pred: deer, Accuracy: 0.000000%
# | Pred: cat, Accuracy: 0.000000%
# | Acctual automobile
# Processed 100/10000
# | Pred: bird, Accuracy: 34.653465%
# | Pred: bird, Accuracy: 41.584158%
# | Acctual bird
# Processed 200/10000
# | Pred: truck, Accuracy: 36.815920%
# | Pred: deer, Accuracy: 41.791045%
# | Acctual truck
# Processed 300/10000
# | Pred: cat, Accuracy: 37.209302%
# | Pred: ship, Accuracy: 42.857143%
# | Acctual automobile
# Processed 400/10000
# | Pred: automobile, Accuracy: 36.658354%
# | Pred: dog, Accuracy: 38.653367%
# | Acctual automobile
# Processed 500/10000
# | Pred: deer, Accuracy: 35.928144%
# | Pred: automobile, Accuracy: 38.722555%
# | Acctual automobile
# Processed 600/10000
# | Pred: frog, Accuracy: 35.274542%
# | Pred: airplane, Accuracy: 38.768719%
# | Acctual ship
# Processed 700/10000
# | Pred: bird, Accuracy: 34.094151%
# | Pred: cat, Accuracy: 37.517832%
# | Acctual dog
# Processed 800/10000
# | Pred: automobile, Accuracy: 33.707865%
# | Pred: automobile, Accuracy: 36.079900%
# | Acctual automobile
# Processed 900/10000
# | Pred: ship, Accuracy: 32.963374%
# | Pred: horse, Accuracy: 35.516093%
# | Acctual truck
# Processed 1000/10000
# | Pred: airplane, Accuracy: 32.167832%
# | Pred: airplane, Accuracy: 35.264735%
# | Acctual airplane
# Processed 1100/10000
# | Pred: dog, Accuracy: 32.970027%
# | Pred: dog, Accuracy: 36.148955%
# | Acctual dog
# Processed 1200/10000
# | Pred: ship, Accuracy: 32.389675%
# | Pred: frog, Accuracy: 36.219817%
# | Acctual truck
# Processed 1300/10000
# | Pred: bird, Accuracy: 32.974635%
# | Pred: frog, Accuracy: 36.664105%
# | Acctual automobile
# Processed 1400/10000
# | Pred: cat, Accuracy: 33.261956%
# | Pred: cat, Accuracy: 37.330478%
# | Acctual dog
# Processed 1500/10000
# | Pred: cat, Accuracy: 32.911392%
# | Pred: deer, Accuracy: 37.641572%
# | Acctual deer
# Processed 1600/10000
# | Pred: bird, Accuracy: 32.604622%
# | Pred: frog, Accuracy: 37.663960%
# | Acctual horse
# Processed 1700/10000
# | Pred: bird, Accuracy: 31.922399%
# | Pred: deer, Accuracy: 37.154615%
# | Acctual dog
# Processed 1800/10000
# | Pred: ship, Accuracy: 31.926707%
# | Pred: ship, Accuracy: 37.756802%
# | Acctual automobile
# Processed 1900/10000
# | Pred: bird, Accuracy: 32.140978%
# | Pred: bird, Accuracy: 37.611783%
# | Acctual ship
# Processed 2000/10000
# | Pred: bird, Accuracy: 32.183908%
# | Pred: bird, Accuracy: 37.381309%
# | Acctual deer
# Processed 2100/10000
# | Pred: dog, Accuracy: 32.270347%
# | Pred: dog, Accuracy: 37.315564%
# | Acctual dog
# Processed 2200/10000
# | Pred: ship, Accuracy: 32.303498%
# | Pred: ship, Accuracy: 37.074057%
# | Acctual automobile
# Processed 2300/10000
# | Pred: airplane, Accuracy: 32.203390%
# | Pred: ship, Accuracy: 36.897001%
# | Acctual deer
# Processed 2400/10000
# | Pred: deer, Accuracy: 32.069971%
# | Pred: ship, Accuracy: 36.817993%
# | Acctual ship
# Processed 2500/10000
# | Pred: bird, Accuracy: 31.987205%
# | Pred: frog, Accuracy: 36.745302%
# | Acctual cat
# Processed 2600/10000
# | Pred: deer, Accuracy: 31.872357%
# | Pred: deer, Accuracy: 36.908881%
# | Acctual deer
# Processed 2700/10000
# | Pred: airplane, Accuracy: 32.173269%
# | Pred: airplane, Accuracy: 37.134395%
# | Acctual airplane
# Processed 2800/10000
# | Pred: ship, Accuracy: 32.631203%
# | Pred: ship, Accuracy: 37.379507%
# | Acctual bird
# Processed 2900/10000
# | Pred: airplane, Accuracy: 32.885212%
# | Pred: airplane, Accuracy: 37.538780%
# | Acctual bird
# Processed 3000/10000
# | Pred: truck, Accuracy: 32.789070%
# | Pred: truck, Accuracy: 37.587471%
# | Acctual automobile
# Processed 3100/10000
# | Pred: cat, Accuracy: 32.279910%
# | Pred: automobile, Accuracy: 37.246050%
# | Acctual dog
# Processed 3200/10000
# | Pred: ship, Accuracy: 32.114964%
# | Pred: frog, Accuracy: 37.269603%
# | Acctual cat
# Processed 3300/10000
# | Pred: bird, Accuracy: 31.960012%
# | Pred: frog, Accuracy: 37.170554%
# | Acctual bird
# Processed 3400/10000
# | Pred: horse, Accuracy: 32.049397%
# | Pred: horse, Accuracy: 37.341958%
# | Acctual horse
# Processed 3500/10000
# | Pred: deer, Accuracy: 31.733790%
# | Pred: deer, Accuracy: 36.989432%
# | Acctual automobile
# Processed 3600/10000
# | Pred: ship, Accuracy: 31.963344%
# | Pred: ship, Accuracy: 37.100805%
# | Acctual truck
# Processed 3700/10000
# | Pred: dog, Accuracy: 32.072413%
# | Pred: dog, Accuracy: 37.206160%
# | Acctual bird
# Processed 3800/10000
# | Pred: airplane, Accuracy: 32.149434%
# | Pred: frog, Accuracy: 37.384899%
# | Acctual frog
# Processed 3900/10000
# | Pred: airplane, Accuracy: 32.299410%
# | Pred: airplane, Accuracy: 37.580108%
# | Acctual dog
# Processed 4000/10000
# | Pred: truck, Accuracy: 32.341915%
# | Pred: truck, Accuracy: 37.565609%
# | Acctual truck
# Processed 4100/10000
# | Pred: dog, Accuracy: 32.333577%
# | Pred: deer, Accuracy: 37.454279%
# | Acctual dog
# Processed 4200/10000
# | Pred: ship, Accuracy: 32.159010%
# | Pred: dog, Accuracy: 37.419662%
# | Acctual automobile
# Processed 4300/10000
# | Pred: deer, Accuracy: 32.201814%
# | Pred: deer, Accuracy: 37.433155%
# | Acctual truck
# Processed 4400/10000
# | Pred: airplane, Accuracy: 32.106339%
# | Pred: airplane, Accuracy: 37.286980%
# | Acctual ship
# Processed 4500/10000
# | Pred: deer, Accuracy: 32.148411%
# | Pred: deer, Accuracy: 37.369473%
# | Acctual horse
# Processed 4600/10000
# | Pred: deer, Accuracy: 32.014779%
# | Pred: deer, Accuracy: 37.187568%
# | Acctual automobile
# Processed 4700/10000
# | Pred: bird, Accuracy: 31.908105%
# | Pred: cat, Accuracy: 37.077218%
# | Acctual deer
# Processed 4800/10000
# | Pred: truck, Accuracy: 31.889190%
# | Pred: bird, Accuracy: 36.971464%
# | Acctual horse
# Processed 4900/10000
# | Pred: frog, Accuracy: 31.850643%
# | Pred: cat, Accuracy: 36.849623%
# | Acctual cat
# Processed 5000/10000
# | Pred: deer, Accuracy: 31.913617%
# | Pred: deer, Accuracy: 37.012597%
# | Acctual horse
# Processed 5100/10000
# | Pred: frog, Accuracy: 31.974123%
# | Pred: frog, Accuracy: 37.012351%
# | Acctual frog
# Processed 5200/10000
# | Pred: deer, Accuracy: 32.051529%
# | Pred: cat, Accuracy: 37.127475%
# | Acctual cat
# Processed 5300/10000
# | Pred: deer, Accuracy: 32.201471%
# | Pred: deer, Accuracy: 37.162799%
# | Acctual deer
# Processed 5400/10000
# | Pred: deer, Accuracy: 32.160711%
# | Pred: bird, Accuracy: 37.104240%
# | Acctual airplane
# Processed 5500/10000
# | Pred: ship, Accuracy: 32.303218%
# | Pred: ship, Accuracy: 37.029631%
# | Acctual ship
# Processed 5600/10000
# | Pred: deer, Accuracy: 32.315658%
# | Pred: deer, Accuracy: 37.029102%
# | Acctual dog
# Processed 5700/10000
# | Pred: frog, Accuracy: 32.327662%
# | Pred: frog, Accuracy: 36.975969%
# | Acctual frog
# Processed 5800/10000
# | Pred: deer, Accuracy: 32.235821%
# | Pred: deer, Accuracy: 37.131529%
# | Acctual cat
# Processed 5900/10000
# | Pred: frog, Accuracy: 32.079309%
# | Pred: frog, Accuracy: 37.129300%
# | Acctual horse
# Processed 6000/10000
# | Pred: deer, Accuracy: 32.127979%
# | Pred: frog, Accuracy: 37.177137%
# | Acctual horse
# Processed 6100/10000
# | Pred: deer, Accuracy: 32.109490%
# | Pred: truck, Accuracy: 37.108671%
# | Acctual bird
# Processed 6200/10000
# | Pred: cat, Accuracy: 32.172230%
# | Pred: cat, Accuracy: 37.123045%
# | Acctual frog
# Processed 6300/10000
# | Pred: ship, Accuracy: 32.232979%
# | Pred: horse, Accuracy: 37.152833%
# | Acctual automobile
# Processed 6400/10000
# | Pred: cat, Accuracy: 32.166849%
# | Pred: cat, Accuracy: 37.056710%
# | Acctual cat
# Processed 6500/10000
# | Pred: bird, Accuracy: 32.102753%
# | Pred: ship, Accuracy: 37.071220%
# | Acctual ship
# Processed 6600/10000
# | Pred: bird, Accuracy: 31.980003%
# | Pred: bird, Accuracy: 36.948947%
# | Acctual frog
# Processed 6700/10000
# | Pred: airplane, Accuracy: 32.039994%
# | Pred: frog, Accuracy: 36.904940%
# | Acctual horse
# Processed 6800/10000
# | Pred: cat, Accuracy: 31.951184%
# | Pred: dog, Accuracy: 36.906337%
# | Acctual dog
# Processed 6900/10000
# | Pred: frog, Accuracy: 31.908419%
# | Pred: frog, Accuracy: 36.965657%
# | Acctual deer
# Processed 7000/10000
# | Pred: airplane, Accuracy: 31.838309%
# | Pred: bird, Accuracy: 36.837595%
# | Acctual bird
# Processed 7100/10000
# | Pred: ship, Accuracy: 31.840586%
# | Pred: bird, Accuracy: 36.797634%
# | Acctual frog
# Processed 7200/10000
# | Pred: dog, Accuracy: 31.870574%
# | Pred: deer, Accuracy: 36.828218%
# | Acctual cat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 classifier = k_nn_Classifier(2, xy_train)
#       2 print(classifier)
# ----> 3 results = classifier.test(xy_test, None, None)
#       4 print(results)
#
# Cell In[2], line 31, in k_nn_Classifier.test(self, test_data, color, metric)
#      29 img_abs_diffs = np.abs(img_diffs)
#      30 gray_distances = np.sum(gray_abs_diffs, axis=1)
# ---> 31 img_distances = np.sum(img_abs_diffs, axis = 1)
#      32 gray_k_indices = np.argpartition(gray_distances, self.k)[:self.k]
#      33 img_k_indices = np.argpartition(img_distances, self.k)[:self.k]
#
# File /usr/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2466, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2463         return out
#    2464     return res
# -> 2466 return _wrapreduction(
#    2467     a, np.add, 'sum', axis, dtype, out,
#    2468     keepdims=keepdims, initial=initial, where=where
#    2469 )
#
# File /usr/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:
